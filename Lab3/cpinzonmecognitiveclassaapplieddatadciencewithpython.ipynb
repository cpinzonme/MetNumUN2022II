# %% [markdown]
# <a href="https://colab.research.google.com/github/cpinzonme/MetNumUN2022II/blob/main/Lab3/cpinzonmecognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Linkedin: www.linkedin.com/in/carlos-daniel-pinzon-medina-604678250

# %% [markdown]
# ![cpinzonmecognitiveclassaapplieddatadciencewithpython.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Certificate - Python for Data Science.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Certificate - Data Analysis with Python.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Certificate - Data Visualization with Python.PNG](data:image/png;base64,...)
